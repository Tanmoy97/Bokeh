# %% [markdown]
# Interactive Data Viscualization with Bokeh
#
# What is Bokeh?
# 1. Interactive , Control & Validating Tools
# 2. Versatile and High Level Graphics
# 3. High Level Statistical Charts
# 4. Streaming , Dunamic and Large Data
# 5. For Browser , with or Without Server Support
# 6. No Java Script Required

# %% [markdown]
# 1. Basic Plotting Same as Matplotlib, Seaborn
# 2. Layout , interactions and annotations (* Example for heatmap we used
#  cmap='coolwarm')
# 3.Statistical Charting ( pie chart)
# 4. For Web Developer - Can Generate Output @ Browser

# %% [markdown]
# What are Glyphs?
# A. Visual Shapes
# 1. circle , square , triangles ....
# 2. Rectangles , lines, wedges
# B. with properties attached to data
# 1. coordinates ( x,y)
# 2. size, color , transparacny ....

# %%
from bokeh.io import output_notebook, show # Import Output_notebook - means - You are getting Output to Your Resepective Noteboon only
from bokeh.plotting import figure

# %%
plot = figure(plot_width=400,tools='pan,box_zoom')
plot.circle([1,2,3,4,5],[8,6,5,2,3])
output_notebook()

# %%
show(plot)
# Out:
#   <div class="bk-root" id="42f62d61-c995-4c1d-942a-8b25729fd6dc" data-root-id="1093"></div>

# %%
# Glyph Properties
# Lists , Array

# %%
plot = figure()
plot.circle(x=10,y=[2,5,6,7,8],size=[10,20,30,40,50])
# Out:
# GlyphRenderer(id='1229', ...)

# %%
show(plot)
# Out:
#   <div class="bk-root" id="a685ff92-2406-4b75-83e4-3b04d5328331" data-root-id="1194"></div>

# %%
# How to Work With Line Plot

# %%
from bokeh.io import output_notebook , show 
from bokeh.plotting import figure

# %%
x = [ 1,2,3,4,5]
y = [8,6,5,2,3]

# %%
plot = figure()

# %%
plot.line(x,y,line_width=5)
# Out:
# GlyphRenderer(id='1446', ...)

# %%
show(plot)
# Out:
#   <div class="bk-root" id="913dd682-fb47-4315-aa42-7ac5b424e381" data-root-id="1314"></div>

# %%
# Lines and Marker Together

# %%
plot = figure()
plot.line(x,y,line_width=3)
plot.circle(x,y,fill_color='white',size=8)
# Out:
# GlyphRenderer(id='1528', ...)

# %%
show(plot)
# Out:
#   <div class="bk-root" id="236d15ee-bb5a-4da2-a83d-bef595f7602e" data-root-id="1488"></div>

# %%
# useful for Showing geographical regions Here We are Taking 3 Regions for x & y

# %%
from bokeh.io import output_notebook , show 
from bokeh.plotting import figure

# %%
x = [[1,1,2,2],[2,2,4],[2,2,3,3]]
y= [[2,5,5,2],[3,5,5],[2,2,4,2]]

# %%
plot = figure()

# %%
plot.patches(x,y,
             fill_color=
             ['red','blue','green'],
             line_color='white')
show(plot)
# Out:
#   <div class="bk-root" id="d474b4fa-5117-45a9-827b-50e374cd7bef" data-root-id="1647"></div>

# %%
# How to Do Basic Python Plotting

# %%
from bokeh.io import output_notebook , show 
from bokeh.plotting import figure

# %%
x = [1,2,3,4,5]
y=[8,6,5,2,3]

# %%
plot=figure()
plot.line(x,y,line_width=3)
plot.circle(x,y,fill_color='white',size=10)
show(plot)
# Out:
#   <div class="bk-root" id="dbfc0097-45b4-4ea4-982f-79e7cdac0eb5" data-root-id="1796"></div>

# %%
# Numpy Arrays

# %%
import numpy as np

# %%
x = np.linspace(0,10,1000)
y = np.sin(x) + np.random.random(1000)*0.2

# %%
plot = figure()
plot.line(x,y)
show(plot)
# Out:
#   <div class="bk-root" id="54a48511-4344-4d55-949a-1bf9fe8b1644" data-root-id="1973"></div>

# %%
import pandas as pd

# %%
# Flowers is a Pandas DataFrame

# %%
from bokeh.io import output_notebook, show 
from bokeh.plotting import figure

# %%
# How to Import Dataset to Bokeh

# %%
from bokeh.sampledata.iris import flowers

# %%
plot = figure()
plot.circle(flowers['petal_length'],
            flowers['sepal_length'],
            size=10)
show(plot)
# Out:
#   <div class="bk-root" id="c0f46e2f-fe48-41a3-a3d2-a11646d2607d" data-root-id="2142"></div>

# %% [markdown]
# Column Data Sorce
# 1. Common Fundamental data Structure of Bokeh
# 2. Maps Strings Column names to Seq.
# 3. Often created automatically
# 4. Can Shared between glyphs

# %%
from bokeh.models import ColumnDataSource

# %%
source = ColumnDataSource(data={
                          'x':[1,2,3,4,5],
                          'y':[8,6,5,2,3]})
source.data
# Out:
# {'x': [1, 2, 3, 4, 5], 'y': [8, 6, 5, 2, 3]}

# %%
from bokeh.models import ColumnDataSource
from bokeh.sampledata.iris import flowers as df

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
source = ColumnDataSource(df)

# %%
plot = figure(tools='box_select,lasso_select') # Anaconda Navigator Version Python 3.5 - Lesso But 3.6 Onward lasso

# %%
plot.circle(petal_length , sepal_length,
            selection_color='red',
            nonslection_fill_alpha=0.4,
            nonslection_fill_color='grey')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-0c44ab4a1b2f> in <module>()
# ----> 1 plot.circle(petal_length , sepal_length,
#       2             selection_color='red',
#       3             nonslection_fill_alpha=0.4,
#       4             nonslection_fill_color='grey')
#
# NameError: name 'petal_length' is not defined

# %%
p = figure(plot_width=400,plot_height=400)

# %%
# Keep a Reference to the Returned GlypherRender

# %%
r = p.circle([1,2,3,4,5],[2,5,8,2,7])

# %%
r.glyph.size=50
r.glyph.fill_alpha=0.3
r.glyph.line_color="firebrick"
r.glyph.line_dash=[5,1]
r.glyph.line_width=2
show(p)
# Out:
#   <div class="bk-root" id="bed110e1-2546-4c59-a6de-c3c3f8ab9374" data-root-id="2366"></div>

# %%
p = figure(plot_width=400,plot_height=400 , tools="tap",title="Test Graph")
renderer=p.circle([1,2,3,4,5],[2,5,8,2,7],size=50,

#Set Visual Properties for Selected Glyphs

selection_color = "firebrick",

# Set Visual Properties for non-selected glyph

nonselection_fill_alpha = 0.2,
nonselection_fill_color='grey',
nonselection_line_color='firebrick',
nonselection_line_alpha=1.0)

show(p)
# Out:
#   <div class="bk-root" id="618b8ec1-905b-4553-986e-10b940d6bfe4" data-root-id="2555"></div>

# %%
from math import pi

p = figure(plot_width=400, plot_height=400)
p.x([1,2,3,4,5],[2,5,8,2,7],size=10, line_width=2)
# Out:
# GlyphRenderer(id='2797', ...)

# %%
p.xaxis.major_label_orientation = pi /4 
p.yaxis.major_label_orientation = "vertical"
show(p)
# Out:
#   <div class="bk-root" id="5a356465-2c7e-4667-93b4-507c11425f61" data-root-id="2762"></div>
